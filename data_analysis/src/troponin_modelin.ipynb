# %%
# Importando o dataset de troponina
import pandas as pd
import numpy as np
import seaborn as sn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression, Lasso, HuberRegressor, RANSACRegressor, SGDRegressor
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler, StandardScaler
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/pedro/Documentos/Workspace/heart_attack_analysis/data/troponin_concentration.csv', index_col=0)
df.head()
correlation = df.corr()
sn.heatmap(correlation, annot=True, fmt='.2f', linewidths=.6)
# Out:
# <Axes: >

# %%
# Como a carga apresenta baixa correlação, pode-se excluí-la
df_final = df.drop(['charge'], axis=1)

# %%
df_final.head()
# Out:
#    anodic_d_peak  cathodic_d_peak  anodic_peak  cathodic_peak  \
# 0     622.173841      -375.174914     82.78919       -121.886
# 1     635.195364      -268.480580     84.18736       -114.475
# 2     611.634197      -417.747769     82.22851       -122.168
# 3     666.173112      -397.214987     90.86034       -128.999
# 4     638.444389      -413.244030     87.18122       -129.212
#
#    delta_anodic_cathodic_V  delta_ano_cat_A  concentration(ng_L)
# 0                 0.183673        204.67519                600.0
# 1                 0.199645        198.66236               1000.0
# 2                 0.177684        204.39651               1200.0
# 3                 0.215617        219.85934               2000.0
# 4                 0.193656        216.39322               2500.0

# %%
# Separando X e Y para regressão
Y = df_final.iloc[:,-1] / 1000
X = df_final[['anodic_d_peak']]

# %%
Y.head()
# Out:
# 0    0.6
# 1    1.0
# 2    1.2
# 3    2.0
# 4    2.5
# Name: concentration(ng_L), dtype: float64

# %%
X.head()
# Out:
#    anodic_d_peak
# 0     622.173841
# 1     635.195364
# 2     611.634197
# 3     666.173112
# 4     638.444389

# %%
# Padronização dos dados
scaler = MinMaxScaler()
scaled_X = scaler.fit_transform(X.values, Y.values)

# %% [markdown]
# ## Regressão Linear

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_X, Y.values, test_size=0.2, random_state=12345)

# %%
# Imprimindo o shape de todos os conjuntos já padronizados
print(x_train.shape)
print(x_test.shape)
print(y_train)
print(y_test)
# Out:
# (7, 1)
# (2, 1)
# [20.   5.   2.5  1.  10.   4.   1.2]
# [2.  0.6]

# %%
def calculate_coeff_determination(lr, x, y, poly = None):
    if (poly != None):
        features = poly.fit_transform(x)
        r_sq = lr.score(features, y)
    else:
        r_sq = lr.score(x, y)
    return r_sq

# %%
lr = LinearRegression()

#Treinando o Modelo
lr.fit(x_train,y_train)
#Verificando o resultado
x_valid = X.values
y_valid = Y.values
scaled_val_x = scaler.transform(x_valid)
r_sq = lr.score(scaled_val_x, y_valid)
print('Coefficient of determination(R²):', r_sq)
# Out:
# Coefficient of determination(R²): 0.8251125755587341

# %%
def plot_regression(x, y, regression_model):
    plt.Figure(figsize=(7,7))
    line_x = np.linspace(x.min(), x.max(), 500)
    line_y = lr.predict(scaler.transform(line_x.reshape(-1,1)))
    plt.scatter(x, y)
    plt.plot(line_x, line_y, color = 'r')
    plt.ylabel('[cTnI] in ng.mL⁻1')
    plt.xlabel('Anodic current in uA')
    plt.show()

# %%
# Observando a reta da regressão Linear
plt.Figure(figsize=(7,7))
line_x = np.linspace(x_valid.min(), x_valid.max(), 500)
line_y = lr.predict(scaler.transform(line_x.reshape(-1,1)))
plt.scatter(x_valid, y_valid)
plt.plot(line_x, line_y, color = 'r')
plt.ylabel('[cTnI] in ng.mL⁻1')
plt.xlabel('Anodic current in uA')
plt.show()
print('Coefficient of determination(R²):', r_sq)
# Out:
# Coefficient of determination(R²): 0.8251125755587341

# %%
def get_coefficients(model_regression):
    # Observando os coeficientes
    coeff_df = pd.DataFrame(model_regression.coef_, columns=['Coefficient'])
    coeff_df['Intercept'] = lr.intercept_
    return coeff_df

# %%
def get_regression_metrics(model_linear, y_test, x_test, model_poly = None):
    out = {
        'MAE': 0,
        'MSE': 0,
        'RMSE':0
    }
    if (model_poly != None):
        if (x_test.shape[1] > 1):
            x_test = model_poly.fit_transform(x_test)
        else:
           x_test = model_poly.fit_transform(x_test.reshape(-1, 1)) 
        
    y_pred = model_linear.predict(x_test)
    out['MAE'] = metrics.mean_absolute_error(y_test, y_pred)
    out['MSE'] = metrics.mean_squared_error(y_test, y_pred)
    out['RMSE'] = np.sqrt(out['MSE'])
    return out

# %%
def print_metrics(metrics:dict):
    for key in metrics.keys():
        print(f'{key}: {metrics[key]}')

# %%
_metrics = get_regression_metrics(lr, y_test, x_test)
print_metrics(_metrics)
# Out:
# MAE: 1.2120565330350672
# MSE: 1.9028419457458794
# RMSE: 1.3794353720801418

# %%
# Observando os coeficientes
coeff_df = pd.DataFrame(lr.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                Coefficient
# anodic_d_peak      15.8948

# %%
# Imprimindo os erros
y_pred = lr.predict(x_test)
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 1.2120565330350672
# MSE: 1.9028419457458794
# RMSE: 1.3794353720801418

# %%
x = np.concatenate((x_train, x_test))
y_true = np.concatenate((y_train, y_test))
y_pred = lr.predict(x)
print(x.shape)
print(y_true.shape)
print(y_pred.shape)
# Out:
# (9, 1)
# (9,)
# (9,)

# %%
print(x)
# Out:
# [[1.        ]
#  [0.53462   ]
#  [0.1465987 ]
#  [0.12883296]
#  [0.88006083]
#  [0.44213151]
#  [0.        ]
#  [0.29821994]
#  [0.057631  ]]

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
degrees = [2, 3, 4, 5, 6, 7, 8]

for degree in degrees:
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    
    if (x_train.shape[1] > 1):
        poly_features = poly.fit_transform(x_train)
    else:
        poly_features = poly.fit_transform(x_train) 
       
    poly_reg_model = LinearRegression()
    poly_reg_model.fit(poly_features, y_train)
    mectrics = get_regression_metrics(poly_reg_model, y_test, x_test, poly)
    r_sq = calculate_coeff_determination(poly_reg_model, x, y_true, poly)
    
    print("Polynom Degree", degree)
    print('Coefficient of determination(R²):', r_sq)
    print('MAE:', mectrics['MAE'])
    print('MSE:', mectrics['MSE'])
    print('RMSE:', mectrics['RMSE'])
    print('------------------------------------------')
    
    # Plotando o polinômio
    line_x = np.linspace(x_valid.min(), x_valid.max(), 500).reshape(-1,1)
    line_x = scaler.transform(line_x)
    line_x_features = poly.fit_transform(line_x)
    line_y = poly_reg_model.predict(line_x_features)
    plt.ylabel('[cTnI] in ng.mL⁻1')
    plt.xlabel('Anodic current in uA')
    plt.scatter(x_valid, y_valid)
    plt.plot(scaler.inverse_transform(line_x), line_y, color='r')
    plt.show()
    print("Coefficients")
    print(get_coefficients(poly_reg_model))
    print("*"*20)
# Out:
# Polynom Degree 2
# Coefficient of determination(R²): 0.9352635574016819
# MAE: 0.5766134737306969
# MSE: 0.5217915799946519
# RMSE: 0.7223514241660024
# ------------------------------------------
# Coefficients
#    Coefficient  Intercept
# 0    -7.084525  -0.869484
# 1    22.791084  -0.869484
# ********************
# Polynom Degree 3
# Coefficient of determination(R²): 0.9623740189652426
# MAE: 1.153098254165424
# MSE: 1.3957837121529315
# RMSE: 1.1814329063272833
# ------------------------------------------
# Coefficients
#    Coefficient  Intercept
# 0    24.678610  -0.869484
# 1   -65.191765  -0.869484
# 2    59.181585  -0.869484
# ********************
# Polynom Degree 4
# Coefficient of determination(R²): 0.9879520720053249
# MAE: 1.0156160711315092
# MSE: 1.2735292360209833
# RMSE: 1.1285075259035642
# ------------------------------------------
# Coefficients
#    Coefficient  Intercept
# 0    -6.464660  -0.869484
# 1   100.765384  -0.869484
# 2  -221.941886  -0.869484
# 3   146.397237  -0.869484
# ********************
# Polynom Degree 5
# Coefficient of determination(R²): 0.9924041973209197
# MAE: 0.8192514305038889
# MSE: 0.6724273245958421
# RMSE: 0.8200166611696631
# ------------------------------------------
# Coefficients
#    Coefficient  Intercept
# 0     6.855291  -0.869484
# 1   -43.688410  -0.869484
# 2   224.864050  -0.869484
# 3  -379.341296  -0.869484
# 4   210.138840  -0.869484
# ********************
# Polynom Degree 6
# Coefficient of determination(R²): 0.8443227493731904
# MAE: 4.897844501464524
# MSE: 24.586281166214956
# RMSE: 4.958455522258413
# ------------------------------------------
# Coefficients
#     Coefficient  Intercept
# 0   -212.535612  -0.869484
# 1   2932.865287  -0.869484
# 2 -12983.745980  -0.869484
# 3  25596.113775  -0.869484
# 4 -23139.138810  -0.869484
# 5   7825.241341  -0.869484
# ********************
# Polynom Degree 7
# Coefficient of determination(R²): 0.8284230474003184
# MAE: 5.0569149109961105
# MSE: 27.09733876512617
# RMSE: 5.205510423111856
# ------------------------------------------
# Coefficients
#     Coefficient  Intercept
# 0   -189.602532  -0.869484
# 1   2454.667571  -0.869484
# 2  -9347.522416  -0.869484
# 3  12922.394504  -0.869484
# 4  -1200.291502  -0.869484
# 5 -10457.929457  -0.869484
# 6   5837.083832  -0.869484
# ********************
# Polynom Degree 8
# Coefficient of determination(R²): 0.8108482595336548
# MAE: 5.223696725966055
# MSE: 29.87294454045022
# RMSE: 5.465614744971532
# ------------------------------------------
# Coefficients
#    Coefficient  Intercept
# 0  -175.007471  -0.869484
# 1  2168.254749  -0.869484
# 2 -7407.056898  -0.869484
# 3  7698.200276  -0.869484
# 4  2857.856564  -0.869484
# 5 -4949.089741  -0.869484
# 6 -4735.878507  -0.869484
# 7  4561.521029  -0.869484
# ********************

# %% [markdown]
# ## Lasso Regression

# %%
lasso = Lasso(alpha=0.1)
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
# Imprimindo os coeficientes
lasso_coeficients = get_coefficients(lasso)
lasso_coeficients
# Out:
#    Coefficient  Intercept
# 0    15.110337  -0.869484

# %%
# Avaliando o modelo
lasso_metrics = get_regression_metrics(lasso, y_test, x_test, None)
print_metrics(lasso_metrics)
r_square = calculate_coeff_determination(lasso, x, y_true, None)
print(f"Coefficient of determination: {r_square}")
# Out:
# MAE: 1.1176899906181306
# MSE: 2.006214063805548
# RMSE: 1.4164088618070518
# Coefficient of determination: 0.8227195441453733

# %%
# Avaliando a regressão Lasso polinomial
degrees = [2, 3, 4]

for degree in degrees:
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    
    if (x_train.shape[1] > 1):
        poly_features = poly.fit_transform(x_train)
    else:
        poly_features = poly.fit_transform(x_train.reshape(-1,1))
    poly_reg_model = Lasso(alpha=0.1)
    poly_reg_model.fit(poly_features, y_train)
    mectrics = get_regression_metrics(poly_reg_model, y_test, x_test, poly)
    r_sq = calculate_coeff_determination(poly_reg_model, x, y_true, poly)
    
    print("Polynom Degree", degree)
    print('Coefficient of determination(R²):', r_sq)
    print('MAE:', mectrics['MAE'])
    print('MSE:', mectrics['MSE'])
    print('RMSE:', mectrics['RMSE'])
    print('------------------------------------------')
# Out:
# Polynom Degree 2
# Coefficient of determination(R²): 0.9257912530561866
# MAE: 0.5815226776685192
# MSE: 0.3395340518598947
# RMSE: 0.5826955052683132
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9462641915948541
# MAE: 0.8178621398192423
# MSE: 0.9115199894192361
# RMSE: 0.9547355599427708
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9573550782885919
# MAE: 0.9480050040493448
# MSE: 1.0522175619158622
# RMSE: 1.0257765652986337
# ------------------------------------------

# %% [markdown]
# # Huber Regressor

# %%
# Avaliando a regressão Lasso polinomial
degrees = [1, 2, 3, 4]

for degree in degrees:
    poly = None
    
    if (degree != 1):
        poly = PolynomialFeatures(degree=degree, include_bias=False)
        
        if (x_train.shape[1] > 1):
            poly_features = poly.fit_transform(x_train)
        else:
           poly_features = poly.fit_transform(x_train.reshape(-1,1))
           
        poly_reg_model = HuberRegressor(alpha=0.001)
        poly_reg_model.fit(poly_features, y_train)
        
    else:
        poly_reg_model = HuberRegressor(alpha=0.001)
        poly_reg_model.fit(x_train, y_train)
        
    mectrics = get_regression_metrics(poly_reg_model, y_test, x_test, poly)
    r_sq = calculate_coeff_determination(poly_reg_model, x, y_true, poly)
    
    print("Polynom Degree", degree)
    print('Coefficient of determination(R²):', r_sq)
    print_metrics(mectrics)
    print('------------------------------------------')
# Out:
# Polynom Degree 1
# Coefficient of determination(R²): 0.7522057976283291
# MAE: 0.8326122098606032
# MSE: 1.1583726842229831
# RMSE: 1.0762772339053648
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9146584717220343
# MAE: 0.33380993706432155
# MSE: 0.19570250687167484
# RMSE: 0.44238276059502457
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9376914805263648
# MAE: 1.0650776373084383
# MSE: 1.1353829687841253
# RMSE: 1.065543508630279
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9570629601744659
# MAE: 1.256273754585326
# MSE: 1.583784725586574
# RMSE: 1.2584850915233656
# ------------------------------------------

# %% [markdown]
# ## RASNAC Regressor

# %%
losses = ['squared_error', 'absolute_error']
for loss in losses:
    print(f"Loss: {loss}")
    print("**"*10)
    for degree in degrees:
        poly = None
        if (degree != 1):
            poly = PolynomialFeatures(degree=degree, include_bias=False)
            if (x_train.shape[1] > 1):
                poly_features = poly.fit_transform(x_train)
            else:
               poly_features = poly.fit_transform(x_train.reshape(-1,1))
               
            poly_reg_model = RANSACRegressor(loss=loss)
            poly_reg_model.fit(poly_features, y_train)
        else:
            poly_reg_model = RANSACRegressor(loss=loss)
            poly_reg_model.fit(x_train, y_train)
        mectrics = get_regression_metrics(poly_reg_model, y_test, x_test, poly)
        r_sq = calculate_coeff_determination(poly_reg_model, x, y_true, poly)
        
        print("Polynom Degree", degree)
        print('Coefficient of determination(R²):', r_sq)
        print_metrics(mectrics)
        print('------------------------------------------')
# Out:
# Loss: squared_error
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.6873356292525398
# MAE: 0.8908414282965976
# MSE: 1.0362084272628227
# RMSE: 1.0179432338116023
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.7987258030162203
# MAE: 0.7670527907666318
# MSE: 0.5885000353175758
# RMSE: 0.7671375595794901
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.932876939739369
# MAE: 0.7379313223385591
# MSE: 0.5513720866091781
# RMSE: 0.7425443330934377
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9879520720053249
# MAE: 1.0156160711315092
# MSE: 1.2735292360209833
# RMSE: 1.1285075259035642
# ------------------------------------------
# Loss: absolute_error
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.6873356292525398
# MAE: 0.8908414282965976
# MSE: 1.0362084272628227
# RMSE: 1.0179432338116023
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.7987258030162203
# MAE: 0.7670527907666318
# MSE: 0.5885000353175758
# RMSE: 0.7671375595794901
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.932876939739369
# MAE: 0.7379313223385591
# MSE: 0.5513720866091781
# RMSE: 0.7425443330934377
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9879520720053249
# MAE: 1.0156160711315092
# MSE: 1.2735292360209833
# RMSE: 1.1285075259035642
# ------------------------------------------

# %% [markdown]
# ## SGD Regressor

# %%
from sklearn.preprocessing import StandardScaler

param = {
    'loss': ['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],
    'alpha': [alpha / 100.0 for alpha in range(1, 11)],
    'epsilon': [epsilon / 100 for epsilon in range(1,11)],
    'learning_rate': ['constant', 'adaptive', 'optimal', 'invscaling']
}

best_param = {
    'loss': None,
    'alpha':None,
    'epsilon': None,
    'learning_rate': None,
    'degree': None
}

min_rmse = np.inf
best_r_square = 0
best_metrics = {}
best_model = None

losses = param['loss']
alphas = param['alpha']
epsilons = param['epsilon']
lrs = param['learning_rate']

scaler = StandardScaler()
new_x = scaler.fit_transform(X.values, Y.values)

n_x_train, n_x_test, n_y_train, n_y_test = train_test_split(new_x, Y, test_size=0.2, random_state=12345)

# print(new_x.shape)

for loss in losses:
    for alpha in alphas:
        for epsilon in epsilons:
            for l in lrs:
                print(f"Loss: {loss}, Apha: {alpha}, Epsilon: {epsilon}, Learning rate: {l}")
                print("**"*10)
                
                for degree in degrees:
                    poly = None
                    
                    if (degree != 1):
                        poly = PolynomialFeatures(degree=degree, include_bias=False)
                        poly_features = poly.fit_transform(n_x_train)
                        poly_reg_model = SGDRegressor(loss=loss, alpha=alpha, learning_rate=l, epsilon=epsilon)
                        poly_reg_model.fit(poly_features, y_train)
                        
                    else:
                        poly_reg_model = SGDRegressor(loss=loss, alpha=alpha, learning_rate=l, epsilon=epsilon)
                        poly_reg_model.fit(n_x_train, y_train)
                        
                    mectrics = get_regression_metrics(poly_reg_model, n_y_test, n_x_test, poly)
                    r_sq = calculate_coeff_determination(poly_reg_model, new_x, Y.values, poly)
                    
                    print("Polynom Degree", degree)
                    print('Coefficient of determination(R²):', r_sq)
                    print_metrics(mectrics)
                    print('------------------------------------------')
                    
                    if (mectrics['RMSE'] < min_rmse):
                        min_rmse = mectrics['RMSE']
                        best_metrics = mectrics
                        best_param['alpha'] = alpha
                        best_param['epsilon'] = epsilon
                        best_param['learning_rate'] = l
                        best_param['loss'] = loss
                        best_param['degree'] = degree
                        best_r_square = r_sq
                        best_model = poly_reg_model
                                        
print(f'Best R²: {best_r_square}')
print_metrics(best_metrics)
print(best_param)
# Out:
# Loss: squared_error, Apha: 0.01, Epsilon: 0.01, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251776448733437
# MAE: 1.180256754750739
# MSE: 1.8517109000298395
# RMSE: 1.360775844887702
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9326891095764792
# MAE: 0.7704193670825883
# MSE: 0.7470877958646691
# RMSE: 0.864342406610175
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.963790794113532
# MAE: 0.9847640040327301
# MSE: 0.970184310408087
# RMSE: 0.9849793451682562
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9866116022492302
# MAE: 1.0296083342698554
# MSE: 1.1790339160100913
# RMSE: 1.0858332818670144
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.01, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251382407573804
# MAE: 1.1969069831186012
# MSE: 1.8908617134966075
# RMSE: 1.3750860749409861
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9341679401291041
# MAE: 0.6806673449774743
# MSE: 0.621034272694732
# RMSE: 0.7880572775469635
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9638423351225387
# MAE: 1.0278842653815627
# MSE: 1.0640505634003672
# RMSE: 1.0315282659240934
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9867802538702162
# MAE: 1.016098484136061
# MSE: 1.1300916122008537
# RMSE: 1.0630576711546997
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.01, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -9363021564906760.0
# MAE: 673071034.4544497
# MSE: 4.625856351499514e+17
# RMSE: 680136482.737069
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -1.0960562471023675e+24
# MAE: 435409723113.81305
# MSE: 1.9010697503328858e+23
# RMSE: 436012585865.6933
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -3.140057070435446e+24
# MAE: 746657578214.6638
# MSE: 7.267750147685122e+23
# RMSE: 852511005658.2919
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -1.1987105892670633e+25
# MAE: 2520925159314.0806
# MSE: 8.3354148470066e+24
# RMSE: 2887111852181.4497
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.01, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.825448565876211
# MAE: 1.175751877468077
# MSE: 1.7300295012308191
# RMSE: 1.3153058584340067
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9241882315061477
# MAE: 1.048334132923836
# MSE: 1.2527997037348484
# RMSE: 1.1192853540249905
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9611837598427732
# MAE: 0.820685451058127
# MSE: 0.7366433588890855
# RMSE: 0.8582793012120736
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9768932029535699
# MAE: 0.7920213711787252
# MSE: 0.6574116936218639
# RMSE: 0.8108092831374489
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.02, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8252466070076719
# MAE: 1.1812443589029578
# MSE: 1.8392016067459007
# RMSE: 1.356171673036235
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9342229689089152
# MAE: 0.6848677365311154
# MSE: 0.6210526494518693
# RMSE: 0.7880689369921069
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.963964505985509
# MAE: 0.9536696790938197
# MSE: 0.9099887591718009
# RMSE: 0.9539333096038742
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9868944086491418
# MAE: 1.0287425119869629
# MSE: 1.1768308023747935
# RMSE: 1.084818326898469
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.02, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8250820751190742
# MAE: 1.195241146193182
# MSE: 1.8985352563276965
# RMSE: 1.3778734543954667
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9304228958619117
# MAE: 0.867123670080254
# MSE: 0.874403344483146
# RMSE: 0.9350953665178467
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9620875756217097
# MAE: 0.8466056640571189
# MSE: 0.7554459659070039
# RMSE: 0.8691639465066437
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9868797913088118
# MAE: 1.0394584943519274
# MSE: 1.1955529042660509
# RMSE: 1.0934134187333038
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.02, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -1.5529941541163382e+21
# MAE: 270136475231.69055
# MSE: 7.389634392318865e+22
# RMSE: 271838819750.21274
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -1.617785174946248e+23
# MAE: 2689048829582.287
# MSE: 7.531660972845279e+24
# RMSE: 2744387176191.6685
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -9.435697128909176e+23
# MAE: 4206214624873.9775
# MSE: 1.845797128554376e+25
# RMSE: 4296274116667.1104
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -4.7168418054284505e+24
# MAE: 3518458338158.264
# MSE: 2.0745142910409413e+25
# RMSE: 4554683623525.284
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.02, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8254513597019135
# MAE: 1.1765206659060288
# MSE: 1.740512191765696
# RMSE: 1.3192847273298118
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9247036431994182
# MAE: 1.0360891541818003
# MSE: 1.22266939379257
# RMSE: 1.10574381924231
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9610048667778921
# MAE: 0.811732183222867
# MSE: 0.7270257915667339
# RMSE: 0.8526580742400401
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9746292958496099
# MAE: 0.7207047288464641
# MSE: 0.5901561899774711
# RMSE: 0.7682162390743059
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.03, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8250954512738027
# MAE: 1.1935318553166765
# MSE: 1.8942015315105765
# RMSE: 1.3762999424219187
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9336695353323891
# MAE: 0.7145321860244034
# MSE: 0.6874688735724532
# RMSE: 0.8291374274343507
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9596074180393324
# MAE: 0.7858200968195055
# MSE: 0.6970933477315626
# RMSE: 0.8349211625845656
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.986698759680225
# MAE: 1.0387334979323932
# MSE: 1.17679447225024
# RMSE: 1.0848015819725927
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.03, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251681143932719
# MAE: 1.195634458552699
# MSE: 1.8841941486685083
# RMSE: 1.3726595166568103
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9334548340404435
# MAE: 0.7312468908247511
# MSE: 0.6938108665070559
# RMSE: 0.8329530998243875
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9640796365898542
# MAE: 1.000431448546216
# MSE: 1.0068914650343908
# RMSE: 1.0034398163489382
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9866609362079835
# MAE: 1.0296537146971332
# MSE: 1.1650155704063685
# RMSE: 1.079358870073512
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.03, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -1.760533787164438e+22
# MAE: 924007677942.5093
# MSE: 8.767916233243277e+23
# RMSE: 936371519923.7574
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -5.4752496350868976e+23
# MAE: 256362980517.58057
# MSE: 9.496423463425157e+22
# RMSE: 308162675602.1105
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -1.2885339933647997e+25
# MAE: 4561962653927.926
# MSE: 2.9990672119223398e+25
# RMSE: 5476373993731.929
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -1.6049505200272438e+25
# MAE: 4928306536171.76
# MSE: 2.8458163015348403e+25
# RMSE: 5334619294321.611
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.03, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251908741271372
# MAE: 1.1635527646681412
# MSE: 1.667119280375631
# RMSE: 1.2911697333718875
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9254645109309373
# MAE: 1.0163970463397187
# MSE: 1.1762716349247757
# RMSE: 1.0845605722709892
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9606607088014739
# MAE: 0.8065962220489242
# MSE: 0.7267755494360238
# RMSE: 0.8525113192421693
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9742141603988554
# MAE: 0.7146287678079599
# MSE: 0.5889700550654052
# RMSE: 0.7674438448938171
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.04, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251729503388845
# MAE: 1.1985730456177106
# MSE: 1.8865668993735856
# RMSE: 1.3735235343355372
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9328335817246983
# MAE: 0.7626396435185829
# MSE: 0.7356211755506066
# RMSE: 0.8576836104010654
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9634755643151268
# MAE: 1.0331022470366187
# MSE: 1.0757612915327617
# RMSE: 1.0371891300687457
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9672318649227692
# MAE: 0.6111657984071521
# MSE: 0.5603274351009642
# RMSE: 0.7485502221634592
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.04, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.825251830902264
# MAE: 1.1975125994188838
# MSE: 1.8711706920704196
# RMSE: 1.3679074135592728
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.93407977039028
# MAE: 0.6899551189450919
# MSE: 0.6366191161407458
# RMSE: 0.7978841495735742
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9636400890034494
# MAE: 1.0516704046405438
# MSE: 1.1169232497209427
# RMSE: 1.0568458968652632
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.986335309771332
# MAE: 1.020344722996903
# MSE: 1.1185915166539533
# RMSE: 1.057634869250231
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.04, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -1.5917723023612953e+20
# MAE: 46924681240.51331
# MSE: 2.90530806096562e+21
# RMSE: 53900909648.776985
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -8.621801289482588e+22
# MAE: 1721195546929.4883
# MSE: 3.019226650040131e+24
# RMSE: 1737592199004.1653
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -6.0078413000830945e+23
# MAE: 3569883621555.088
# MSE: 1.6260525835101503e+25
# RMSE: 4032434231962.315
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -2.1522523136589283e+24
# MAE: 2681941174362.049
# MSE: 7.329952453972272e+24
# RMSE: 2707388493358.918
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.04, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8254538840463465
# MAE: 1.1764294407334355
# MSE: 1.73660797560108
# RMSE: 1.3178042250657265
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9286838418964858
# MAE: 0.9245870608317056
# MSE: 0.9840811932999709
# RMSE: 0.9920086659399558
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9589158184875068
# MAE: 0.7599643706287236
# MSE: 0.6964186554151167
# RMSE: 0.8345170192483294
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9785706369265728
# MAE: 0.8428519199977809
# MSE: 0.7199634800175001
# RMSE: 0.8485066175449076
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.05, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.82520436586377
# MAE: 1.1915837666264084
# MSE: 1.8717865017007556
# RMSE: 1.3681324868961908
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.933508096329378
# MAE: 0.7226976089592738
# MSE: 0.659281495208178
# RMSE: 0.8119615109154977
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9638033826572638
# MAE: 1.0078459618967146
# MSE: 1.0206901006806286
# RMSE: 1.0102920868148124
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9816930992050964
# MAE: 1.0447467161659962
# MSE: 1.1773289168441674
# RMSE: 1.0850478868898679
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.05, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251352627728644
# MAE: 1.1849463167528471
# MSE: 1.872284331670477
# RMSE: 1.3683144125786577
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9341329651803583
# MAE: 0.6869979933592665
# MSE: 0.643582136902447
# RMSE: 0.8022357115601667
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9619391252571041
# MAE: 0.8473009472288566
# MSE: 0.7596949688453758
# RMSE: 0.8716048237850544
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9856253423920893
# MAE: 1.0096478655178083
# MSE: 1.0775272531426623
# RMSE: 1.0380401018952314
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.05, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -6.16192680609414e+22
# MAE: 453942237460.83167
# MSE: 2.1038834711994958e+23
# RMSE: 458681095228.4273
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -5.773009207248527e+23
# MAE: 1478731637578.0034
# MSE: 2.2503270712811948e+24
# RMSE: 1500109019798.626
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -3.3409309665857463e+24
# MAE: 2317218994962.967
# MSE: 6.998160327789362e+24
# RMSE: 2645403622850.2754
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -1.198635602760402e+25
# MAE: 1473038506516.9773
# MSE: 2.1702347893335227e+24
# RMSE: 1473171676802.647
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.05, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8254765635532789
# MAE: 1.1817026533954305
# MSE: 1.7709767360608841
# RMSE: 1.3307804988279939
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9297298531921573
# MAE: 0.8904443315272587
# MSE: 0.9236054326711007
# RMSE: 0.9610439285855256
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9609912716978879
# MAE: 0.8147985656229038
# MSE: 0.7320270816404673
# RMSE: 0.8555858119677227
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9783712276179237
# MAE: 0.8357015716857095
# MSE: 0.7105702641747778
# RMSE: 0.8429532989286997
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.06, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251713844875719
# MAE: 1.1952406842642564
# MSE: 1.883126541005725
# RMSE: 1.372270578641736
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.933918582881947
# MAE: 0.7042181188484653
# MSE: 0.6552694399478433
# RMSE: 0.8094871462523932
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.962260503385289
# MAE: 0.8721482341014888
# MSE: 0.778768510843602
# RMSE: 0.8824786177826645
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9863023149498498
# MAE: 1.0129241224141032
# MSE: 1.1362362128503143
# RMSE: 1.0659438131769958
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.06, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8253198262974553
# MAE: 1.1946203714534473
# MSE: 1.853822567286771
# RMSE: 1.3615515294276492
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9337581402123238
# MAE: 0.7133333729104321
# MSE: 0.6705687515145539
# RMSE: 0.8188826237712911
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.959732973636196
# MAE: 0.778771103668684
# MSE: 0.7050248628319743
# RMSE: 0.8396575866577841
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9864444924722418
# MAE: 1.0222345037804057
# MSE: 1.1295418924352456
# RMSE: 1.0627990837572479
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.06, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -7.105968154057353e+22
# MAE: 1325397543678.4846
# MSE: 1.7719054974974573e+24
# RMSE: 1331129406743.5583
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -6.17459205117248e+22
# MAE: 1003137445117.2092
# MSE: 1.015571865152575e+24
# RMSE: 1007755855925.7173
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -3.682556154172204e+24
# MAE: 3434723091300.773
# MSE: 1.5283689840247303e+25
# RMSE: 3909436000275.1426
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -2.4315862584968354e+25
# MAE: 5710407109267.416
# MSE: 3.2734712109427134e+25
# RMSE: 5721425706013.068
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.06, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8254021495299755
# MAE: 1.1725715935221137
# MSE: 1.7149502044843508
# RMSE: 1.3095610732166525
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9281844334097585
# MAE: 0.9398911685539497
# MSE: 1.0154912119262982
# RMSE: 1.0077158388783507
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9608631397356163
# MAE: 0.8116762480414716
# MSE: 0.7298863896114872
# RMSE: 0.8543338864937333
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9768596312074402
# MAE: 0.7930537635533987
# MSE: 0.65948912779435
# RMSE: 0.8120893594884432
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.07, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8252228079464294
# MAE: 1.194360425744799
# MSE: 1.8725458467915637
# RMSE: 1.368409970290908
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9313353804585951
# MAE: 0.8309683523745748
# MSE: 0.8302088594571303
# RMSE: 0.9111579772230117
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9636175948520044
# MAE: 1.0263259261043098
# MSE: 1.06229342368435
# RMSE: 1.0306761973017278
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9819480518325863
# MAE: 1.0483325238366097
# MSE: 1.180007532484734
# RMSE: 1.0862815162216164
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.07, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251996263325321
# MAE: 1.194848232862132
# MSE: 1.8775145971670948
# RMSE: 1.3702242871760428
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9339009537645824
# MAE: 0.7033674620523407
# MSE: 0.6551051196561576
# RMSE: 0.8093856433469508
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9638227121442551
# MAE: 1.01869728630305
# MSE: 1.0421303451343544
# RMSE: 1.020847856016926
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9773010737714318
# MAE: 0.8030082721981466
# MSE: 0.6701886701652076
# RMSE: 0.8186505177212114
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.07, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -4.016625550335039e+19
# MAE: 43775841183.493744
# MSE: 1.9870683352595237e+21
# RMSE: 44576544676.09085
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -9.378246709786646e+22
# MAE: 1227477745823.5928
# MSE: 1.5199132416072249e+24
# RMSE: 1232847614917.2795
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -1.1846787303299044e+24
# MAE: 1959296482550.4783
# MSE: 4.216783281084493e+24
# RMSE: 2053480772026.973
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -1.2684377147605664e+26
# MAE: 8983779141135.016
# MSE: 1.2372399133928814e+26
# RMSE: 11123128666849.455
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.07, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8254276121047017
# MAE: 1.1743256214552356
# MSE: 1.726749934907598
# RMSE: 1.314058573621282
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9274937784393796
# MAE: 0.9597522901555104
# MSE: 1.0476527677010394
# RMSE: 1.0235491037077993
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9587885945788559
# MAE: 0.7576163603730117
# MSE: 0.6959930253108539
# RMSE: 0.83426196443974
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9784778880696321
# MAE: 0.8404712375720267
# MSE: 0.7168480171459073
# RMSE: 0.8466687765271065
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.08, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8252119020127366
# MAE: 1.197200561482772
# MSE: 1.8781824015609416
# RMSE: 1.3704679498481318
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9340136644417649
# MAE: 0.6889638636546356
# MSE: 0.6262127345134695
# RMSE: 0.7913360439872996
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9636161851355479
# MAE: 0.9687085538321931
# MSE: 0.9418100209956278
# RMSE: 0.9704689696201666
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9787518138996587
# MAE: 1.0364288884510133
# MSE: 1.1382140572559807
# RMSE: 1.0668711530714385
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.08, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.825210124046156
# MAE: 1.1926374004083822
# MSE: 1.8723803973541577
# RMSE: 1.3683495157868686
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9331952510206246
# MAE: 0.7455026154262603
# MSE: 0.711192051521131
# RMSE: 0.8433220331054626
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9639773513077718
# MAE: 1.0148850201551325
# MSE: 1.0373569768994022
# RMSE: 1.0185072296745872
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9863465632068759
# MAE: 1.0176174446927502
# MSE: 1.1134165039763897
# RMSE: 1.0551855305946862
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.08, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -1.2101098487249397e+21
# MAE: 211447065064.14987
# MSE: 4.879793527927434e+22
# RMSE: 220902547018.5311
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -1.1014939168676322e+23
# MAE: 1713433723141.4485
# MSE: 3.9233888889340896e+24
# RMSE: 1980754626129.6702
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -5.240973295427868e+24
# MAE: 1485343851780.9592
# MSE: 2.2090024906918542e+24
# RMSE: 1486271338178.8179
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -5.776226586173673e+23
# MAE: 2719172214976.688
# MSE: 7.550019204581244e+24
# RMSE: 2747729827435.959
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.08, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8253749929841284
# MAE: 1.1710181533584636
# MSE: 1.7087119103255302
# RMSE: 1.3071770768819082
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9257609700040114
# MAE: 1.0086447712054243
# MSE: 1.1598322653935593
# RMSE: 1.0769550897755948
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9600243709926679
# MAE: 0.7853276681507417
# MSE: 0.7094852821503745
# RMSE: 0.8423094930904997
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.97689689390971
# MAE: 0.7935592649136785
# MSE: 0.6600936362141587
# RMSE: 0.8124614675257891
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.09, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8252072814187121
# MAE: 1.196970614182938
# MSE: 1.8787565019395718
# RMSE: 1.3706773879872578
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9331062658555939
# MAE: 0.7490751019905472
# MSE: 0.7241854526014782
# RMSE: 0.8509908651692321
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9606661539116832
# MAE: 0.8256665163527019
# MSE: 0.7537031431004972
# RMSE: 0.8681607818258651
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9670651517219047
# MAE: 0.7178075674779985
# MSE: 0.6160975432885011
# RMSE: 0.7849188131829311
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.09, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251414557357966
# MAE: 1.198067475422674
# MSE: 1.8915042497586858
# RMSE: 1.3753196900207187
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9341758229539875
# MAE: 0.6892453317280801
# MSE: 0.6276793114960639
# RMSE: 0.7922621482161469
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.963912740770675
# MAE: 1.031286137188957
# MSE: 1.076694482565297
# RMSE: 1.0376388979627245
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9867077614661242
# MAE: 1.0289655497831955
# MSE: 1.1634511967790262
# RMSE: 1.0786339493910926
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.09, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -2.826281721218943e+22
# MAE: 1156750275427.5522
# MSE: 1.356804507615781e+24
# RMSE: 1164819517185.2937
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -2.3855616698047214e+23
# MAE: 1718752492733.2302
# MSE: 3.168983928383652e+24
# RMSE: 1780164017270.2212
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -1.8280519977450684e+24
# MAE: 2391151157168.7305
# MSE: 6.700400942371846e+24
# RMSE: 2588513268726.248
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -3.206937895531454e+25
# MAE: 5514251313275.528
# MSE: 3.958055410534164e+25
# RMSE: 6291307821537.716
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.09, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8253390001281453
# MAE: 1.1692369486706817
# MSE: 1.6979724152691014
# RMSE: 1.3030627058085507
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9265645310688052
# MAE: 0.9866630339355604
# MSE: 1.1113444237322425
# RMSE: 1.0542032174738618
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9607377422002291
# MAE: 0.8090423473732076
# MSE: 0.7288327832169414
# RMSE: 0.8537170393151009
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9767806852456014
# MAE: 0.7900240772664406
# MSE: 0.6560555715303922
# RMSE: 0.8099725745544674
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.1, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251605867781332
# MAE: 1.1960830476275324
# MSE: 1.886057431009243
# RMSE: 1.3733380614434463
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.933758558077374
# MAE: 0.7120892304604273
# MSE: 0.6652627398483825
# RMSE: 0.8156364017430698
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9637389127953327
# MAE: 1.0337584399682402
# MSE: 1.0757562178144568
# RMSE: 1.0371866841675403
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9867023415484135
# MAE: 1.0203712909322433
# MSE: 1.147507308852198
# RMSE: 1.0712176757560519
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.1, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.825210124046156
# MAE: 1.1926374004083822
# MSE: 1.8723803973541577
# RMSE: 1.3683495157868686
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9328867313849378
# MAE: 0.7636692755361042
# MSE: 0.7249827519844855
# RMSE: 0.8514591898526233
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9639807738741225
# MAE: 0.9579010766276461
# MSE: 0.9175770753022682
# RMSE: 0.9579024351687745
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9760977224049973
# MAE: 0.755664969445988
# MSE: 0.6187067724337012
# RMSE: 0.786579158402828
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.1, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -2.50707393312374e+19
# MAE: 33178192282.5077
# MSE: 1.1070778023816395e+21
# RMSE: 33272778699.435963
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -2.510255183291728e+23
# MAE: 2177344765202.0024
# MSE: 5.612054659464624e+24
# RMSE: 2368977555711.456
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -2.4234823392744453e+24
# MAE: 3641757730134.8345
# MSE: 1.5388460716409791e+25
# RMSE: 3922812857683.8574
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -2.0539799102391794e+25
# MAE: 4202057916430.116
# MSE: 1.766774701732627e+25
# RMSE: 4203301918412.032
# ------------------------------------------
# Loss: squared_error, Apha: 0.01, Epsilon: 0.1, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8254827898013736
# MAE: 1.1801406873679368
# MSE: 1.7566079560156924
# RMSE: 1.3253708748933983
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9256956004714909
# MAE: 1.009485543624883
# MSE: 1.1529399819474606
# RMSE: 1.0737504281477426
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.960981229320248
# MAE: 0.8144887692207672
# MSE: 0.7316361439579967
# RMSE: 0.8553573194624552
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9746957860209392
# MAE: 0.7261014198846245
# MSE: 0.5960988103130721
# RMSE: 0.7720743554302734
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.01, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251491283445417
# MAE: 1.176715243025842
# MSE: 1.8467891430826144
# RMSE: 1.3589662038044266
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9329741696274672
# MAE: 0.7428536837118994
# MSE: 0.7056052865237809
# RMSE: 0.8400031467344518
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9638809456479394
# MAE: 0.9610133296479562
# MSE: 0.9237896261060098
# RMSE: 0.961139753681019
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9804960677783598
# MAE: 1.0174849943847584
# MSE: 1.0569551708668483
# RMSE: 1.028083250941697
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.01, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8250667889330178
# MAE: 1.1804061580586043
# MSE: 1.874721428196098
# RMSE: 1.3692046699438685
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9334355247747621
# MAE: 0.7254344554635419
# MSE: 0.7033640049544723
# RMSE: 0.8386679944736608
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.963865473875703
# MAE: 0.9604068274009712
# MSE: 0.922546271687082
# RMSE: 0.9604927233910114
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9762454115998875
# MAE: 0.7713247550811329
# MSE: 0.6384017584569239
# RMSE: 0.7990004746287226
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.01, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -41858358.406377256
# MAE: 36862.88940796288
# MSE: 1359514262.7496521
# RMSE: 36871.59154077367
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -8.467406846272042e+22
# MAE: 480765799534.2395
# MSE: 2.3664184698676288e+23
# RMSE: 486458474062.0343
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -6.225472229766529e+23
# MAE: 607094901441.4078
# MSE: 3.755048350843177e+23
# RMSE: 612784493181.9977
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -4.594798494850303e+24
# MAE: 3962551513187.3613
# MSE: 1.5702054972365902e+25
# RMSE: 3962581856866.291
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.01, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251001701375835
# MAE: 1.1578409174643018
# MSE: 1.7183201142094782
# RMSE: 1.3108470979521136
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9250599904361745
# MAE: 1.0229373356314209
# MSE: 1.2013700830472676
# RMSE: 1.096070291106947
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9609432894302508
# MAE: 0.8106324849889681
# MSE: 0.7270007300661234
# RMSE: 0.852643378011067
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9768164140650023
# MAE: 0.7997145637063792
# MSE: 0.6707944500462191
# RMSE: 0.8190204210190483
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.02, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8248916235364965
# MAE: 1.167025583630134
# MSE: 1.866827820995334
# RMSE: 1.3663190773005163
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9317144737395519
# MAE: 0.8131279775366619
# MSE: 0.8161686140157421
# RMSE: 0.9034205078565253
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9633945059633617
# MAE: 0.9979275965696721
# MSE: 1.002149140094197
# RMSE: 1.0010739933162769
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9704517422972964
# MAE: 0.6540838109754277
# MSE: 0.579966131992459
# RMSE: 0.7615550748254909
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.02, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8249410529763814
# MAE: 1.1720970232606254
# MSE: 1.8750556587624776
# RMSE: 1.3693267173185797
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9332789786205946
# MAE: 0.739503751688698
# MSE: 0.7072441502083288
# RMSE: 0.8409780913961604
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9639934985489698
# MAE: 0.9698340954296687
# MSE: 0.9407494239172585
# RMSE: 0.9699223803569327
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9861048933535621
# MAE: 1.0391031824754524
# MSE: 1.1566918710943481
# RMSE: 1.0754961046393186
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.02, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -61532341471.79361
# MAE: 1285386.908874184
# MSE: 1660746383311.3738
# RMSE: 1288699.493020531
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -3.5749023655430036e+20
# MAE: 37564161481.63575
# MSE: 1.8806155784397636e+21
# RMSE: 43366064825.38811
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -6.463400484137875e+23
# MAE: 1905609228924.5947
# MSE: 4.4313387398573136e+24
# RMSE: 2105074521212.3284
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -3.997712519501446e+23
# MAE: 3157733987727.9717
# MSE: 1.0870707663347747e+25
# RMSE: 3297075622934.322
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.02, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.824925338481043
# MAE: 1.1513062949372734
# MSE: 1.6827154863993838
# RMSE: 1.2971952383505667
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9289131681042386
# MAE: 0.9145147345624227
# MSE: 0.98395494052808
# RMSE: 0.9919450289850138
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9614890489696816
# MAE: 0.8318801513929084
# MSE: 0.7468929258461228
# RMSE: 0.8642296719310919
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9789615870576478
# MAE: 0.8671760292976654
# MSE: 0.7578521817095409
# RMSE: 0.8705470588713403
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.03, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8249342000512443
# MAE: 1.1787718304715338
# MSE: 1.8951455756413287
# RMSE: 1.3766428642321613
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9337429002484872
# MAE: 0.7050330806321483
# MSE: 0.6882521649749255
# RMSE: 0.8296096461438509
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9637359826557009
# MAE: 1.012070800194701
# MSE: 1.0338988433654228
# RMSE: 1.016808164486017
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9675086280544727
# MAE: 0.6384534458927744
# MSE: 0.5640628510321332
# RMSE: 0.7510411779870216
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.03, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8249738309403551
# MAE: 1.1805380062615387
# MSE: 1.892253469716276
# RMSE: 1.375592043345801
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9339405734330218
# MAE: 0.6945518719820705
# MSE: 0.6557413035355489
# RMSE: 0.809778552158273
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9635672766945449
# MAE: 0.9161724843763634
# MSE: 0.8449405655034092
# RMSE: 0.9192064868697398
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9857582720690562
# MAE: 1.0275276244522025
# MSE: 1.1176284727911852
# RMSE: 1.057179489392026
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.03, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -59446110.33388821
# MAE: 29765.811913713136
# MSE: 931536419.0671241
# RMSE: 30521.0815513986
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -1.0018636536574626e+23
# MAE: 1621485752074.78
# MSE: 2.7537322808757414e+24
# RMSE: 1659437338640.9448
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -4.945178742743977e+23
# MAE: 2626005561048.283
# MSE: 7.975212849196015e+24
# RMSE: 2824041934744.5986
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -5.494663200003413e+25
# MAE: 3036039772097.2876
# MSE: 1.5574918134963045e+25
# RMSE: 3946507080313.3047
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.03, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251925251708834
# MAE: 1.164583199465474
# MSE: 1.766505971288078
# RMSE: 1.3290996844812197
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9265243739581067
# MAE: 0.9846019566360991
# MSE: 1.1113840328253348
# RMSE: 1.05422200357673
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9616125418664766
# MAE: 0.8358094967970624
# MSE: 0.7504388992506916
# RMSE: 0.866278765323664
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9741057496627382
# MAE: 0.7166802951016749
# MSE: 0.5938010940805694
# RMSE: 0.7705849038753415
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.04, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8248394585134208
# MAE: 1.1653610728576596
# MSE: 1.871003271362837
# RMSE: 1.367846216269518
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9330458113958773
# MAE: 0.7396850352174322
# MSE: 0.6874693396977392
# RMSE: 0.8291377085247897
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9636495259832896
# MAE: 0.9553595326886304
# MSE: 0.9127193254966803
# RMSE: 0.9553634520415151
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9736397100436801
# MAE: 0.9411692853301867
# MSE: 0.8864402087993319
# RMSE: 0.9415095372853809
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.04, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8249054970639328
# MAE: 1.1684536495340423
# MSE: 1.8694349668008698
# RMSE: 1.3672728209106146
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.93210355766134
# MAE: 0.7941584238743562
# MSE: 0.7939237066352878
# RMSE: 0.8910239652418378
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9639405391679698
# MAE: 0.9843940588591487
# MSE: 0.9698081873623073
# RMSE: 0.9847883972520733
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9858498515887015
# MAE: 1.0311764982108715
# MSE: 1.1337710171670208
# RMSE: 1.0647868411879537
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.04, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -95869206.34085545
# MAE: 61173.291889038424
# MSE: 3746049515.188937
# RMSE: 61204.97949667933
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -1.2591551585440477e+22
# MAE: 417665328796.8804
# MSE: 1.84224994713126e+23
# RMSE: 429214392481.3403
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -3.195096952508831e+23
# MAE: 754215511524.0138
# MSE: 5.786716435785724e+23
# RMSE: 760704701956.3981
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -3.880190536928029e+24
# MAE: 2146850516840.4314
# MSE: 4.675701544486304e+24
# RMSE: 2162337056170.0837
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.04, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8251526823533517
# MAE: 1.1606802494177304
# MSE: 1.73725139566327
# RMSE: 1.3180483282730076
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9283778993012468
# MAE: 0.9315876529181351
# MSE: 1.0166176221949947
# RMSE: 1.0082745767869954
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9586338237412796
# MAE: 0.7416741030019869
# MSE: 0.676562377308722
# RMSE: 0.8225341192368387
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9772629749374732
# MAE: 0.8143232497081763
# MSE: 0.6878823612765175
# RMSE: 0.8293867380640454
# ------------------------------------------
# Loss: squared_error, Apha: 0.02, Epsilon: 0.05, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8250409996179027
# MAE: 1.1790744206574553
# MSE: 1.8762300002793517
# RMSE: 1.3697554527284612
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9326817942721322
# MAE: 0.7647803257272008
# MSE: 0.756218253378551
# RMSE: 0.8696081033307768
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9639165086536323
# MAE: 0.9456201967360398
# MSE: 0.8942307536403782
# RMSE: 0.9456377496908519
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9850078931401695
# MAE: 1.0395466785714647
# MSE: 1.1427197442834804
# RMSE: 1.0689807034196082
# ------------------------------------------
# ...
# RMSE: 0.8778020348909253
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9627018782857221
# MAE: 1.1316122306312728
# MSE: 1.3095165118685776
# RMSE: 1.1443410819631434
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9819151165500405
# MAE: 1.0064159613357215
# MSE: 1.0173008970361879
# RMSE: 1.0086133535880772
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.06, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -13054.595803879663
# MAE: 245.08786882805703
# MSE: 84652.05382553066
# RMSE: 290.9502600540695
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -5.428544080086643e+18
# MAE: 3578376631.63453
# MSE: 1.6108620769512735e+19
# RMSE: 4013554630.189146
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -1.2910148404209108e+23
# MAE: 508261556616.5385
# MSE: 2.916423160994408e+23
# RMSE: 540039180152.18195
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -1.4627620669235908e+23
# MAE: 794807425814.4631
# MSE: 6.477437828333521e+23
# RMSE: 804825311998.4187
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.06, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8239732462037486
# MAE: 1.129381578101637
# MSE: 1.8436064639780154
# RMSE: 1.3577947061238733
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9313127667078654
# MAE: 0.7924423258301814
# MSE: 0.8585630476051374
# RMSE: 0.9265867728416682
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9641652233260977
# MAE: 0.9656914607078522
# MSE: 0.9338391567399029
# RMSE: 0.9663535361035851
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9798960046993388
# MAE: 0.9474374982317861
# MSE: 0.8988338150462039
# RMSE: 0.948068465379059
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.07, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.824003306158051
# MAE: 1.147219283458251
# MSE: 1.9481395447935421
# RMSE: 1.3957576955881497
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.930737125435745
# MAE: 0.7839916884186915
# MSE: 0.7936403112316822
# RMSE: 0.8908649231121867
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9595639637864479
# MAE: 1.0578381076208234
# MSE: 1.1623354157062253
# RMSE: 1.0781166058020928
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9778991836935809
# MAE: 1.0634024225455811
# MSE: 1.1708506919569788
# RMSE: 1.082058543682817
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.07, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8231430264647932
# MAE: 1.1289188311003104
# MSE: 2.0006025788884694
# RMSE: 1.4144265901376676
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9322210953348915
# MAE: 0.7468232465585357
# MSE: 0.7840356348822439
# RMSE: 0.8854578673670723
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9630668210516441
# MAE: 1.10970155147049
# MSE: 1.2615145886201762
# RMSE: 1.1231716648047065
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9826588894418815
# MAE: 1.0235543432764316
# MSE: 1.057326502895204
# RMSE: 1.0282638294208368
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.07, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8228882064623299
# MAE: 1.1161086952069403
# MSE: 1.9683667334423867
# RMSE: 1.402984936997681
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -1.1267488089479523e+17
# MAE: 198897967.66710693
# MSE: 6.4332461495136744e+16
# RMSE: 253638446.40577805
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -1.6773074132044307e+21
# MAE: 102379286155.90686
# MSE: 1.1051400432852952e+22
# RMSE: 105125641176.89343
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -2.0886366966597647e+23
# MAE: 100556681112.74368
# MSE: 1.6367981130515237e+22
# RMSE: 127937410988.79263
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.07, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8240265714860292
# MAE: 1.1282431922648026
# MSE: 1.8156374638157988
# RMSE: 1.3474559227729117
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9318359871700905
# MAE: 0.7731526674154628
# MSE: 0.8409506661280477
# RMSE: 0.9170336232265683
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9641785399171728
# MAE: 0.9446702095923818
# MSE: 0.8925509568886841
# RMSE: 0.9447491502450183
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9804752125543504
# MAE: 0.9594501787566527
# MSE: 0.9206115403330697
# RMSE: 0.9594850391397823
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.08, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8237512918491385
# MAE: 1.145541430809357
# MSE: 1.9810603728358938
# RMSE: 1.407501464594582
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9267971501833848
# MAE: 0.9731371659485665
# MSE: 1.1471430262659832
# RMSE: 1.07104763025086
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9596233937666498
# MAE: 1.0628407987276416
# MSE: 1.1779000364941794
# RMSE: 1.0853110321443247
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9825148187823406
# MAE: 1.0078561609553558
# MSE: 1.030169549132156
# RMSE: 1.0149726839339845
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.08, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8231520382136569
# MAE: 1.1358218548825743
# MSE: 2.0299752758597203
# RMSE: 1.4247720083787863
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.932270857300861
# MAE: 0.7579314994186861
# MSE: 0.8154002721991747
# RMSE: 0.9029951673177297
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9641412141097793
# MAE: 0.943425052348309
# MSE: 0.8900763588709414
# RMSE: 0.9434385824583079
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9850727398861948
# MAE: 1.059175545996444
# MSE: 1.168747585602595
# RMSE: 1.081086298869149
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.08, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.7891552909808986
# MAE: 0.9932885945043053
# MSE: 1.651263902651126
# RMSE: 1.2850151371291803
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -1.4886919436264862e+19
# MAE: 6384560020.162414
# MSE: 4.982286027778614e+19
# RMSE: 7058531028.322121
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -2.313484971712994e+22
# MAE: 42851055665.73729
# MSE: 2.0174251902925595e+21
# RMSE: 44915756592.67647
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -4.5540112736008945e+23
# MAE: 872651750184.8779
# MSE: 8.470054153069817e+23
# RMSE: 920328971241.7955
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.08, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8240628388516253
# MAE: 1.133094321091152
# MSE: 1.8535471016063438
# RMSE: 1.36145036692725
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9292628693382241
# MAE: 0.8827135963779263
# MSE: 0.9847003160703929
# RMSE: 0.9923206719958991
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.963222408767358
# MAE: 0.8626995817767553
# MSE: 0.7600769393651463
# RMSE: 0.8718239153436583
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9818456766543275
# MAE: 1.0015712019095453
# MSE: 1.0059748284044905
# RMSE: 1.0029829651616673
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.09, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8229074650082434
# MAE: 1.1101901103523282
# MSE: 1.9193417476081696
# RMSE: 1.3854030993209772
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9226148354328574
# MAE: 1.0528896921156874
# MSE: 1.2766994550050486
# RMSE: 1.1299112597921346
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9602022737840006
# MAE: 1.0874021928890008
# MSE: 1.2119651355465477
# RMSE: 1.10089288104999
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9790652203936885
# MAE: 1.0201842938126633
# MSE: 1.0412368262135694
# RMSE: 1.0204101264754135
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.09, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8237081876436527
# MAE: 1.1405445560590233
# MSE: 1.9669384805079462
# RMSE: 1.402475839545176
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9320201849901396
# MAE: 0.7735091981617068
# MSE: 0.8361648732842113
# RMSE: 0.9144205122831679
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9642067290477861
# MAE: 0.9316241797868712
# MSE: 0.8679241548019343
# RMSE: 0.9316244709119305
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.982101835636034
# MAE: 0.9979966259913446
# MSE: 0.9990201512674126
# RMSE: 0.9995099555619307
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.09, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): -241.1525930006982
# MAE: 28.042878548891437
# MSE: 892.6482205999129
# RMSE: 29.877219090804164
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -4.3596543905347315e+17
# MAE: 1126236655.2574136
# MSE: 1.5319175939067968e+18
# RMSE: 1237706586.3551009
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -4.207382100975652e+22
# MAE: 485940811156.31476
# MSE: 2.4792718027314266e+23
# RMSE: 497922865786.6022
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -1.988665922438996e+23
# MAE: 595415303940.5782
# MSE: 4.43898710372305e+23
# RMSE: 666257240390.1552
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.09, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8240123809302521
# MAE: 1.135262415925651
# MSE: 1.8819466219201344
# RMSE: 1.3718405963960005
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9301144198188034
# MAE: 0.8453390081855564
# MSE: 0.924822485698238
# RMSE: 0.9616769133644822
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9641434896117298
# MAE: 0.937458959332766
# MSE: 0.8788587191240131
# RMSE: 0.9374746498567378
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9813311506424619
# MAE: 0.9942422059545797
# MSE: 0.989392948163518
# RMSE: 0.9946823353028433
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.1, Learning rate: constant
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8227924252149089
# MAE: 1.1090420972689403
# MSE: 1.9329832632379766
# RMSE: 1.390317684285853
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9320612917979486
# MAE: 0.7631571714284178
# MSE: 0.8668041864469573
# RMSE: 0.9310231932916373
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9625072229506597
# MAE: 1.1045897109781018
# MSE: 1.2491015461637676
# RMSE: 1.117632115753555
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9824730535962177
# MAE: 1.0224984323332074
# MSE: 1.0806401111028248
# RMSE: 1.0395384125191454
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.1, Learning rate: adaptive
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.8230195844191344
# MAE: 1.1376029074351035
# MSE: 2.0548291990322696
# RMSE: 1.4334675437666071
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9325559681343167
# MAE: 0.7213702916944347
# MSE: 0.7733343586599364
# RMSE: 0.8793943135249036
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9628538710795127
# MAE: 1.1200865449926387
# MSE: 1.2820719561731868
# RMSE: 1.1322861635528303
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9814733395013767
# MAE: 0.9949954542335278
# MSE: 0.9912354810273609
# RMSE: 0.9956080961037636
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.1, Learning rate: optimal
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.823175708980305
# MAE: 1.1283301152111604
# MSE: 1.9925823334704076
# RMSE: 1.4115885850595447
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): -148718380637189.4
# MAE: 19900124.706171557
# MSE: 486564456912879.0
# RMSE: 22058206.1127572
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): -7.755970800485854e+22
# MAE: 98915462834.63939
# MSE: 1.5551358736096966e+22
# RMSE: 124705087049.79507
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): -3.337664207843528e+23
# MAE: 606668438290.2216
# MSE: 4.7440299612313236e+23
# RMSE: 688769189295.7556
# ------------------------------------------
# Loss: squared_epsilon_insensitive, Apha: 0.1, Epsilon: 0.1, Learning rate: invscaling
# ********************
# Polynom Degree 1
# Coefficient of determination(R²): 0.823838248042936
# MAE: 1.1358601805356356
# MSE: 1.9207393474695884
# RMSE: 1.3859074094143478
# ------------------------------------------
# Polynom Degree 2
# Coefficient of determination(R²): 0.9300345047365671
# MAE: 0.8471806144861536
# MSE: 0.9291296109375842
# RMSE: 0.9639136947556997
# ------------------------------------------
# Polynom Degree 3
# Coefficient of determination(R²): 0.9643575621694236
# MAE: 0.9410004566805064
# MSE: 0.88655403916151
# RMSE: 0.941569986332142
# ------------------------------------------
# Polynom Degree 4
# Coefficient of determination(R²): 0.9821389486366386
# MAE: 1.00776763707346
# MSE: 1.01946290792805
# RMSE: 1.0096845586261334
# ------------------------------------------
# Best R²: 0.861064186462655
# MAE: 0.06014146198636844
# MSE: 0.004844693784258554
# RMSE: 0.06960383455139921
# {'loss': 'epsilon_insensitive', 'alpha': 0.03, 'epsilon': 0.08, 'learning_rate': 'optimal', 'degree': 2}

# %%
best_coefficients = get_coefficients(best_model)
best_coefficients
# Out:
#    Coefficient  Intercept
# 0     3.676479  -0.869484
# 1     1.297749  -0.869484

# %%
# Plotando para verificar o modelo
import matplotlib.pyplot as plt
plt.Figure()
plt.scatter(scaler.inverse_transform(new_x), Y, label = 'true')
x_values = np.linspace(X.min(), X.max(), 500)
new_x_values = scaler.transform(x_values)
poly = PolynomialFeatures(degree=best_param['degree'], include_bias=False)
poly_features = poly.fit_transform(new_x_values.reshape(-1, 1))
pred = best_model.predict(poly_features)
plt.plot(scaler.inverse_transform(new_x_values), pred, color='red', label = 'pred')
plt.ylabel('[cTnI] in (ng/L)')
plt.xlabel('Anodic current peak in uA')
plt.legend()
plt.show()

# %% [markdown]
# ## Utilizando o Support Vector Regression

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV


param = {
    'kernel': ['poly', 'linear', 'rbf', 'sigmoid'],
    'C': [c for c in range(1,11)],
    'degree': [1, 2, 3, 4]
}

# Separando X e Y para regressão
Y = df_final.iloc[:,-1].values / 1000
X = df_final.values

scaled_x = scaler.fit_transform(X, Y)
x_train, x_test, y_train, y_test = train_test_split(scaled_x, Y, random_state=12345)

base_regressor = SVR()
clf = GridSearchCV(base_regressor, param)
clf.fit(x_train, y_train)
print(clf.best_estimator_)
mae = metrics.mean_absolute_error(y_test, clf.best_estimator_.predict(x_test))
msr = metrics.mean_squared_error(y_test, clf.best_estimator_.predict(x_test))

print(mae)
print(msr)
print(np.sqrt(msr))
print(clf.best_estimator_.score(scaled_x, Y))
# if (n_x_train.shape[1] > 1):
#     n_y_train = StandardScaler().fit_transform(n_x_train)
# else:
#     n_y_train = StandardScaler().fit_transform(n_x_train.reshape(-1,1))

# base_regressor.fit(n_x_train, n_y_train)
# print(f"Best Parameters: {base_regressor.get_params()}" )
# results = get_regression_metrics(base_regressor, n_y_test, n_x_test)
# print_metrics(results)
# Out:
# SVR(C=1, degree=1, kernel='poly')
# 4.4288256146252465
# 48.19342084953285
# 6.9421481437328065
# 0.4999775191037047

# %% [markdown]
# # Desision Tree regressor

# %%
from sklearn.tree import DecisionTreeRegressor
param = {
    'criterion': ['squared_error', 'firedman_mse', 'absolute_error', 'poisson']
}

decision_tree = DecisionTreeRegressor(random_state=12345)
clf = GridSearchCV(decision_tree, param, cv=2)
clf.fit(x_train, y_train)
print(clf.best_estimator_)
mae = metrics.mean_absolute_error(y_test, clf.best_estimator_.predict(x_test))
msr = metrics.mean_squared_error(y_test, clf.best_estimator_.predict(x_test))

print(mae)
print(msr)
print(np.sqrt(msr))
print(clf.best_estimator_.score(scaled_x, Y))
print(clf.best_estimator_.get_params())
# Out:
# DecisionTreeRegressor(random_state=12345)
# 3.6333333333333333
# 33.47
# 5.785326265648291
# 0.6821082328441375
# {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 12345, 'splitter': 'best'}

# %% [markdown]
# # KNN - Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
param = {
    'n_neighbors': [2, 3],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'metric': ['minkowski', 'euclidian']
}

knn_r = KNeighborsRegressor()
base_regressor = SVR()
clf = GridSearchCV(knn_r, param, refit = True, verbose = 3,n_jobs=-1, cv=2)
clf.fit(x_train, y_train)
print(clf.best_params_)
mae = metrics.mean_absolute_error(y_test, clf.best_estimator_.predict(x_test))
msr = metrics.mean_squared_error(y_test, clf.best_estimator_.predict(x_test))

print(mae)
print(msr)
print(np.sqrt(msr))
print(clf.best_estimator_.score(scaled_x, Y))
print(clf.best_estimator_.get_params())
# Out:
# Fitting 2 folds for each of 32 candidates, totalling 64 fits
# [CV 2/2] END algorithm=auto, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.025 total time=   0.0s[CV 1/2] END algorithm=auto, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.196 total time=   0.0s
#
# [CV 2/2] END algorithm=auto, metric=minkowski, n_neighbors=2, weights=distance;, score=0.188 total time=   0.0s
# [CV 1/2] END algorithm=auto, metric=minkowski, n_neighbors=2, weights=distance;, score=0.751 total time=   0.0s
# [CV 1/2] END algorithm=auto, metric=minkowski, n_neighbors=3, weights=uniform;, score=-1.832 total time=   0.0s
# [CV 2/2] END algorithm=auto, metric=minkowski, n_neighbors=3, weights=uniform;, score=-0.370 total time=   0.0s
# [CV 1/2] END algorithm=auto, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=auto, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=auto, metric=minkowski, n_neighbors=3, weights=distance;, score=0.289 total time=   0.0s
# [CV 2/2] END algorithm=auto, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=auto, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=auto, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=auto, metric=minkowski, n_neighbors=3, weights=distance;, score=-0.004 total time=   0.0s
# [CV 2/2] END algorithm=auto, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=auto, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=auto, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=2, weights=distance;, score=0.751 total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.196 total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=3, weights=distance;, score=0.289 total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=3, weights=uniform;, score=-1.832 total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=2, weights=distance;, score=0.188 total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=3, weights=distance;, score=-0.004 total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=3, weights=uniform;, score=-0.370 total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.025 total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=ball_tree, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.196 total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=2, weights=distance;, score=0.751 total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=3, weights=uniform;, score=-1.832 total time=   0.0s
# [CV 2/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.025 total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=3, weights=distance;, score=0.289 total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s[CV 2/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=2, weights=distance;, score=0.188 total time=   0.0s
#
# [CV 2/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=3, weights=uniform;, score=-0.370 total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=kd_tree, metric=minkowski, n_neighbors=3, weights=distance;, score=-0.004 total time=   0.0s
# [CV 1/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=kd_tree, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.196 total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=minkowski, n_neighbors=2, weights=uniform;, score=0.025 total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=minkowski, n_neighbors=2, weights=distance;, score=0.751 total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=minkowski, n_neighbors=2, weights=distance;, score=0.188 total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=minkowski, n_neighbors=3, weights=uniform;, score=-0.370 total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=minkowski, n_neighbors=3, weights=uniform;, score=-1.832 total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=minkowski, n_neighbors=3, weights=distance;, score=-0.004 total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=minkowski, n_neighbors=3, weights=distance;, score=0.289 total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=euclidian, n_neighbors=2, weights=uniform;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=euclidian, n_neighbors=2, weights=distance;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=euclidian, n_neighbors=3, weights=uniform;, score=nan total time=   0.0s
# [CV 1/2] END algorithm=brute, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# [CV 2/2] END algorithm=brute, metric=euclidian, n_neighbors=3, weights=distance;, score=nan total time=   0.0s
# {'algorithm': 'ball_tree', 'metric': 'minkowski', 'n_neighbors': 2, 'weights': 'distance'}
# 4.319357395047548
# 47.10594471754701
# 6.863377063628882
# 0.5525965936717241
# {'algorithm': 'ball_tree', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 2, 'p': 2, 'weights': 'distance'}
